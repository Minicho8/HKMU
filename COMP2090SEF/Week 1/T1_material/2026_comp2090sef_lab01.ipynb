# %% [markdown]
# # COMP2090SEF Lab 1
# ## Python Basics (Review)
#
# **Input your name and SID.**
#
# **Note: If you cannot complete the assignment during class, please finish it in your own time after the tutorial session.**
#
# ***Hint: Click to select a block. Press Shift + Enter to execute a block.***

# %%
name = input("Name: ")
sid = input("Student ID: ")
print(name, "\t", sid)

# %% [markdown]
# ### Exercise 1 (String literal) (Work Together)
# Write a single Python statement to print "Homantin", "Kowloon", and "Hong Kong" (enclosed with double quotes) at three different lines.
#
# **Expected Output:**
# ```
# "Homantin"
# "Kowloon"
# "Hong Kong"
# ```
#
# ***Notice:*** Your output need to show the double qoutes

# %%
# Your solution

print(   )

# %% [markdown]
# ### Exercise 2 (Decision structure) (Try it by yourself)
# Design a program to check if a student can pass this course according to his or her OCAS and OES. Assume the passing threshold is **40** for both components. The student must obtain a passing grade for both OCAS and OES to pass the course.
#
# **Test cases** (the test cases are for you to test if your program works well)
#
# case 1: ocas = 80, oes = 20, output: You cannot pass the course. Work harder!
#
# case 2: ocas = 20, oes = 90, output: You cannot pass the course. Work harder!
#
# case 3: ocas = 40, oes = 40, output: Congratulation, you can pass the course!

# %%
ocas = input("Input your OCAS: ")
oes = input("Input your OES: ")
status = False

# TODO (your solution)



if status == True:
    print("Congratulation, you can pass the course!")
else:
    print("You cannot pass the course. Work harder!")

# %% [markdown]
# ### Exercise 3 (Repetition structure)
# In this activity, you will print out patterns with asterisk sign (\*) by using both condition-based (while) loop and count-based (for) loop. You must use repetition structures, either for-loop or while-loop, to complete this task. You must not print the patterns line-by-line.

# %% [markdown]
# #### Case 1: (Be noted that the pattern starts from 1 asterisk sign, not 0)(Work Together)
#
# ```
# *
# **
# ***
# ****
# *****
# ******
# *******
# ```
#
# Your solution (both while-loop and for-loop can be used):

# %%
# Your solution

#TODO

# %% [markdown]
# #### Case 2: (Be noted that the pattern starts from / ends by 1 asterisk sign, not 0) (Try it by yourself)
# Try to use ONE structure to do both the incremental and decremental steps
#
# ```
# *
# **
# ***
# ****
# *****
# ******
# *******
# ******
# *****
# ****
# ***
# **
# *
# ```
#
# Your solution (both while-loop and for-loop can be used):

# %%
# Your solution

#TODO

# %% [markdown]
# ### Exercise 4 (the ```range()``` method) (Work Together)
# Review the usage of built-in function ```range()```, and write down the results of the following question. Running the following codes to check whether your answer is correct.
#
# ```
# #a
# for i in range(1,7,2):
#     print(i, end = " ")
#
#
# #b
# alist = [1, 3, 5, 7, 9]
# for i in alist[-3:]:
#     print(i, end = "*")
#
# #c
# alist = []
# for i in range(5, 0, -1):
#     alist.append(str(i))
# print(alist)
#
#
# ```

# %%
#a

# %%
#b

# %%
#c

# %% [markdown]
# ### Exercise 5 (string methods)
# Review the usage of string methods to manipulate strings.
#
# **Q1** (Work Together)
#
# Given a string, use proper string methods to perform the following operations:
#
# (a) Convert the string to lowercase as a new string variable ```astring_1```
#
# (b) Split the original string into a list by spaces as separator
#
# (c) Split the original string into a list by the letter ```'a'``` as separator
#
# (d) Split the lowercased string (```astring_1```) into a list by the letter ```'e'``` as separator
#
# (e) Concatenate the items in ```astrlist_4``` into a string with spaces

# %%
astring = "Today's exam of COMP1080SEF is EASY to all"

# %%
# a
astring_1 =  #TODO

# %%
# b
astrlist_2 =  #TODO

# %%
# c
astrlist_3 =  #TODO

# %%
# d
astrlist_4 =  #TODO

# %%
# e
astring_5 =   #TODO

# %%
print(astring_1)
print(astrlist_2)
print(astrlist_3)
print(astrlist_4)
print(astring_5)
# Out:
# today's exam of comp1080sef is easy to all
# ["Today's", 'exam', 'of', 'COMP1080SEF', 'is', 'EASY', 'to', 'all']
# ['Tod', "y's ex", 'm of COMP1080SEF is EASY to ', 'll']
# ["today's ", 'xam of comp1080s', 'f is ', 'asy to all']
# today's  xam of comp1080s f is  asy to all

# %% [markdown]
# **Expected Output**:
#
# ```
# today's exam of comp1080sef is easy to all
# ["Today's", 'exam', 'of', 'COMP1080SEF', 'is', 'EASY', 'to', 'all']
# ['Tod', "y's ex", 'm of COMP1080SEF is EASY to ', 'll']
# ["today's ", 'xam of comp1080s', 'f is ', 'asy to all']
# today's  xam of comp1080s f is  asy to all
# ```

# %% [markdown]
# **Q2 (Try it by yourself)**
#
# What are the outputs of the following programs? Test your answer in Jupyter Notebook

# %% [markdown]
# (a)
# ```
# for day in ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]:
#     if day == "Fri":
#         break
#     print(day, end = " ")
#
# ```
#
# (b)
# ```
# for day in ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]:
#     if day <= "Tomorrow":
#         continue
#     print(day, end = " ")
#
# ```

# %% [markdown]
# ### Exercise 6 (string methods) (Work Together)
#
# Complete the following program to
#
# (a) read the text file ```hk_universities.txt```;
#
# (b) print the names of universities in the **ascending order**. Note that there is **NO** extra blank between the lines.
#
# (c) create a dictionary ```unit_dict``` that contains the short-name and full-name of each university as a key-value pair, i.e., short-name is the key and full-name is the value;
#
# (d) write the names in **ascending order** in a new file called ```sorted_hk_universities.txt```.

# %%
# define a new dictionary
uni_dict = {}

# open the file for reading and read lines as list
#TODO
fin = #TODO

# fort the list according to the strings
#TODO

# open a new file for writing
fout = open('sorted_universities.txt', 'w')

# iterate through the sorted list
for i in f:
    
    # write the sorted strings line by line
    #TODO
    
    
    # remove the '\n' at the end of the line
    #TODO
    
    
    # split each line according to '\t' to obtain the short-name and full-name
    #TODO

    
    # add a new key-value pair to the dictionary
    #TODO
    

print(uni_dict)
# Out:
# City University of Hong Kong	CityU
# Hong Kong Baptist University	HKBU
# Lingnan University	LU
# The Chinese University of Hong Kong	CUHK
# The Education University of Hong Kong	EdUHK
# The Hong Kong Polytechnic University	PolyU
# The Hong Kong University of Science and Technology	HKUST
# The University of Hong Kong	HKU
# {'CityU': 'City University of Hong Kong', 'HKBU': 'Hong Kong Baptist University', 'LU': 'Lingnan University', 'CUHK': 'The Chinese University of Hong Kong', 'EdUHK': 'The Education University of Hong Kong', 'PolyU': 'The Hong Kong Polytechnic University', 'HKUST': 'The Hong Kong University of Science and Technology', 'HKU': 'The University of Hong Kong'}

# %% [markdown]
# **Expected Output:**
# ```
# City University of Hong Kong	CityU
# Hong Kong Baptist University	HKBU
# Lingnan University	LU
# The Chinese University of Hong Kong	CUHK
# The Education University of Hong Kong	EdUHK
# The Hong Kong Polytechnic University	PolyU
# The Hong Kong University of Science and Technology	HKUST
# The University of Hong Kong	HKU
# {'CityU': 'City University of Hong Kong', 'HKBU': 'Hong Kong Baptist University', 'LU': 'Lingnan University', 'CUHK': 'The Chinese University of Hong Kong', 'EdUHK': 'The Education University of Hong Kong', 'PolyU': 'The Hong Kong Polytechnic University', 'HKUST': 'The Hong Kong University of Science and Technology', 'HKU': 'The University of Hong Kong'}
# ```
#
# There will be a new file in the same folder:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### END of Lab 1
